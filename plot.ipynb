# %%
gpt_3_5 = [19, 7, 12, 9, 14, 9, 36, 19, 14, 22, 14, 9, 12, 10, 32, 15, 18, 4, 20, 30, 20, 5, 44, 18, 9, 12, 39, 8, 15, 7, 26, 11, 15, 12, 25, 23, 12, 12, 9, 12, 15, 12, 15, 34, 19, 7, 23, 6, 16, 18, 16, 15, 22, 7, 13, 16, 7, 13, 11, 10, 18, 10, 30, 14, 14, 11, 12, 10, 8, 15, 21, 17, 11, 9, 23, 19, 21, 15, 10, 10, 11, 13, 12, 29, 11, 15, 18, 13, 14, 11]
length=44
version = 2
model = "gpt_3_5" #gpt_3_5, gemini
task = "keyword_counting"
# [7, 8, 3, 6, 0, 3, 14, 6, 21, 4, 30, 1, 1, 0, 0, 32, 7, 16, 2, 4, 3, 12, 0, 8, 3, 6, 5, 4, 11, 3, 24, 4, 3, 4, 17, 1, 9, 3, 5, 1, 11, 4, 0, 1, 12, 9, 5, 6, 4, 3, 15, 3, 7, 7, 2, 6, 7, 5, 2, 9, 11, 9, 4, 1, 6, 3, 19, 10, 23, 8, 1, 9, 3, 4, 2, 10, 1, 6, 9, 4, 11, 5]
y_lower = 0
y_upper = length

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(dpi=150, figsize=(2.5, 5))

# %%
scores_ordered = [score for score in gpt_3_5]
ax.boxplot(scores_ordered, positions=range(1))

fig_fontsize = 12

# Set the ticks and labels
plt.yticks(fontsize=fig_fontsize)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0.0, '0.0'),
#   Text(0, 0.2, '0.2'),
#   Text(0, 0.4, '0.4'),
#   Text(0, 0.6000000000000001, '0.6'),
#   Text(0, 0.8, '0.8'),
#   Text(0, 1.0, '1.0')])

# %%
ax.set_ylim(y_lower, (y_upper + 2))
# Out:
# (0.0, 46.0)

# %%
ax1_yticks = range(
            y_lower, y_upper + 1, 3 if length < 48 else (4 if length < 96 else 8)
        )
ax.set_yticks(ax1_yticks)

# %%
fig.savefig(f"{model}_{task}_{length}_v{version}.png", bbox_inches="tight")
